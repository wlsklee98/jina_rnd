# %%
import os
import collections
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.sparse as sp
import torch
from torch import Tensor
import torch_geometric
from torch_geometric.utils import to_networkx
from torch_geometric.datasets import Planetoid
import networkx as nx
from networkx.algorithms import community
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
from skt.vault_utils import get_secrets
proxies = get_secrets('proxies')
os.environ['http_proxy'] = proxies['http']
os.environ['https_proxy'] = proxies['https']

# %%
data_dir = "../../../data"

# %%
dataset = Planetoid(root=data_dir, name='Cora')
data = dataset[0]
# Out:
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# File /opt/conda/envs/custom/lib/python3.8/site-packages/aiohttp/connector.py:992, in TCPConnector._wrap_create_connection(self, req, timeout, client_error, *args, **kwargs)
#     989     async with ceil_timeout(
#     990         timeout.sock_connect, ceil_threshold=timeout.ceil_threshold
#     991     ):
# --> 992         return await self._loop.create_connection(*args, **kwargs)
#     993 except cert_errors as exc:
#
# File /opt/conda/envs/custom/lib/python3.8/asyncio/base_events.py:1025, in BaseEventLoop.create_connection(self, protocol_factory, host, port, ssl, family, proto, flags, sock, local_addr, server_hostname, ssl_handshake_timeout, happy_eyeballs_delay, interleave)
#    1024 if len(exceptions) == 1:
# -> 1025     raise exceptions[0]
#    1026 else:
#    1027     # If they all have the same str(), raise one.
#
# File /opt/conda/envs/custom/lib/python3.8/asyncio/base_events.py:1010, in BaseEventLoop.create_connection(self, protocol_factory, host, port, ssl, family, proto, flags, sock, local_addr, server_hostname, ssl_handshake_timeout, happy_eyeballs_delay, interleave)
#    1009 try:
# -> 1010     sock = await self._connect_sock(
#    1011         exceptions, addrinfo, laddr_infos)
#    1012     break
#
# File /opt/conda/envs/custom/lib/python3.8/asyncio/base_events.py:924, in BaseEventLoop._connect_sock(self, exceptions, addr_info, local_addr_infos)
#     923         raise my_exceptions.pop()
# --> 924 await self.sock_connect(sock, address)
#     925 return sock
#
# File /opt/conda/envs/custom/lib/python3.8/asyncio/selector_events.py:496, in BaseSelectorEventLoop.sock_connect(self, sock, address)
#     495 self._sock_connect(fut, sock, address)
# --> 496 return await fut
#
# File /opt/conda/envs/custom/lib/python3.8/asyncio/selector_events.py:528, in BaseSelectorEventLoop._sock_connect_cb(self, fut, sock, address)
#     526     if err != 0:
#     527         # Jump to any except clause below.
# --> 528         raise OSError(err, f'Connect call failed {address}')
#     529 except (BlockingIOError, InterruptedError):
#     530     # socket is still registered, the callback will be retried later
#
# TimeoutError: [Errno 110] Connect call failed ('20.200.245.247', 443)
#
# The above exception was the direct cause of the following exception:
#
# ClientConnectorError                      Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 dataset = Planetoid(root=data_dir, name='Cora')
#       2 data = dataset[0]
#
# File /opt/conda/envs/custom/lib/python3.8/site-packages/torch_geometric/datasets/planetoid.py:102, in Planetoid.__init__(self, root, name, split, num_train_per_class, num_val, num_test, transform, pre_transform, force_reload)
#      99 self.split = split.lower()
#     100 assert self.split in ['public', 'full', 'geom-gcn', 'random']
# --> 102 super().__init__(root, transform, pre_transform,
#     103                  force_reload=force_reload)
#     104 self.load(self.processed_paths[0])
#     106 if split == 'full':
#
# File /opt/conda/envs/custom/lib/python3.8/site-packages/torch_geometric/data/in_memory_dataset.py:82, in InMemoryDataset.__init__(self, root, transform, pre_transform, pre_filter, log, force_reload)
#      73 def __init__(
#      74     self,
#      75     root: Optional[str] = None,
#    (...)
#      80     force_reload: bool = False,
#      81 ) -> None:
# ---> 82     super().__init__(root, transform, pre_transform, pre_filter, log,
#      83                      force_reload)
#      85     self._data: Optional[BaseData] = None
#      86     self.slices: Optional[Dict[str, Tensor]] = None
#
# File /opt/conda/envs/custom/lib/python3.8/site-packages/torch_geometric/data/dataset.py:115, in Dataset.__init__(self, root, transform, pre_transform, pre_filter, log, force_reload)
#     112 self.force_reload = force_reload
#     114 if self.has_download:
# --> 115     self._download()
#     117 if self.has_process:
#     118     self._process()
#
# File /opt/conda/envs/custom/lib/python3.8/site-packages/torch_geometric/data/dataset.py:232, in Dataset._download(self)
#     229     return
#     231 fs.makedirs(self.raw_dir, exist_ok=True)
# --> 232 self.download()
#
# File /opt/conda/envs/custom/lib/python3.8/site-packages/torch_geometric/datasets/planetoid.py:154, in Planetoid.download(self)
#     152 def download(self) -> None:
#     153     for name in self.raw_file_names:
# --> 154         fs.cp(f'{self.url}/{name}', self.raw_dir)
#     155     if self.split == 'geom-gcn':
#     156         for i in range(10):
#
# File /opt/conda/envs/custom/lib/python3.8/site-packages/torch_geometric/io/fs.py:111, in cp(path1, path2, extract, log, use_cache, clear_cache)
#     101 def cp(
#     102     path1: str,
#     103     path2: str,
#    (...)
#     107     clear_cache: bool = True,
#     108 ) -> None:
#     109     kwargs: Dict[str, Any] = {}
# --> 111     is_path1_dir = isdir(path1)
#     112     is_path2_dir = isdir(path2)
#     114     # Cache result if the protocol is not local:
#
# File /opt/conda/envs/custom/lib/python3.8/site-packages/torch_geometric/io/fs.py:59, in isdir(path)
#      58 def isdir(path: str) -> bool:
# ---> 59     return get_fs(path).isdir(path)
#
# File /opt/conda/envs/custom/lib/python3.8/site-packages/fsspec/asyn.py:118, in sync_wrapper.<locals>.wrapper(*args, **kwargs)
#     115 @functools.wraps(func)
#     116 def wrapper(*args, **kwargs):
#     117     self = obj or args[0]
# --> 118     return sync(self.loop, func, *args, **kwargs)
#
# File /opt/conda/envs/custom/lib/python3.8/site-packages/fsspec/asyn.py:103, in sync(loop, func, timeout, *args, **kwargs)
#     101     raise FSTimeoutError from return_result
#     102 elif isinstance(return_result, BaseException):
# --> 103     raise return_result
#     104 else:
#     105     return return_result
#
# File /opt/conda/envs/custom/lib/python3.8/site-packages/fsspec/asyn.py:56, in _runner(event, coro, result, timeout)
#      54     coro = asyncio.wait_for(coro, timeout=timeout)
#      55 try:
# ---> 56     result[0] = await coro
#      57 except Exception as ex:
#      58     result[0] = ex
#
# File /opt/conda/envs/custom/lib/python3.8/site-packages/fsspec/implementations/http.py:513, in HTTPFileSystem._isdir(self, path)
#     510 async def _isdir(self, path):
#     511     # override, since all URLs are (also) files
#     512     try:
# --> 513         return bool(await self._ls(path))
#     514     except (FileNotFoundError, ValueError):
#     515         return False
#
# File /opt/conda/envs/custom/lib/python3.8/site-packages/fsspec/implementations/http.py:204, in HTTPFileSystem._ls(self, url, detail, **kwargs)
#     202     out = self.dircache[url]
#     203 else:
# --> 204     out = await self._ls_real(url, detail=detail, **kwargs)
#     205     self.dircache[url] = out
#     206 return out
#
# File /opt/conda/envs/custom/lib/python3.8/site-packages/fsspec/implementations/http.py:159, in HTTPFileSystem._ls_real(self, url, detail, **kwargs)
#     157 logger.debug(url)
#     158 session = await self.set_session()
# --> 159 async with session.get(self.encode_url(url), **self.kwargs) as r:
#     160     self._raise_not_found_for_status(r, url)
#     161     text = await r.text()
#
# File /opt/conda/envs/custom/lib/python3.8/site-packages/aiohttp/client.py:1194, in _BaseRequestContextManager.__aenter__(self)
#    1193 async def __aenter__(self) -> _RetType:
# -> 1194     self._resp = await self._coro
#    1195     return self._resp
#
# File /opt/conda/envs/custom/lib/python3.8/site-packages/aiohttp/client.py:578, in ClientSession._request(self, method, str_or_url, params, data, json, cookies, headers, skip_auto_headers, auth, allow_redirects, max_redirects, compress, chunked, expect100, raise_for_status, read_until_eof, proxy, proxy_auth, timeout, verify_ssl, fingerprint, ssl_context, ssl, server_hostname, proxy_headers, trace_request_ctx, read_bufsize, auto_decompress, max_line_size, max_field_size)
#     573     async with ceil_timeout(
#     574         real_timeout.connect,
#     575         ceil_threshold=real_timeout.ceil_threshold,
#     576     ):
#     577         assert self._connector is not None
# --> 578         conn = await self._connector.connect(
#     579             req, traces=traces, timeout=real_timeout
#     580         )
#     581 except asyncio.TimeoutError as exc:
#     582     raise ServerTimeoutError(
#     583         "Connection timeout " "to host {}".format(url)
#     584     ) from exc
#
# File /opt/conda/envs/custom/lib/python3.8/site-packages/aiohttp/connector.py:544, in BaseConnector.connect(self, req, traces, timeout)
#     541         await trace.send_connection_create_start()
#     543 try:
# --> 544     proto = await self._create_connection(req, traces, timeout)
#     545     if self._closed:
#     546         proto.close()
#
# File /opt/conda/envs/custom/lib/python3.8/site-packages/aiohttp/connector.py:911, in TCPConnector._create_connection(self, req, traces, timeout)
#     909     _, proto = await self._create_proxy_connection(req, traces, timeout)
#     910 else:
# --> 911     _, proto = await self._create_direct_connection(req, traces, timeout)
#     913 return proto
#
# File /opt/conda/envs/custom/lib/python3.8/site-packages/aiohttp/connector.py:1235, in TCPConnector._create_direct_connection(self, req, traces, timeout, client_error)
#    1233 else:
#    1234     assert last_exc is not None
# -> 1235     raise last_exc
#
# File /opt/conda/envs/custom/lib/python3.8/site-packages/aiohttp/connector.py:1204, in TCPConnector._create_direct_connection(self, req, traces, timeout, client_error)
#    1197 server_hostname = (
#    1198     (req.server_hostname or hinfo["hostname"]).rstrip(".")
#    1199     if sslcontext
#    1200     else None
#    1201 )
#    1203 try:
# -> 1204     transp, proto = await self._wrap_create_connection(
#    1205         self._factory,
#    1206         host,
#    1207         port,
#    1208         timeout=timeout,
#    1209         ssl=sslcontext,
#    1210         family=hinfo["family"],
#    1211         proto=hinfo["proto"],
#    1212         flags=hinfo["flags"],
#    1213         server_hostname=server_hostname,
#    1214         local_addr=self._local_addr,
#    1215         req=req,
#    1216         client_error=client_error,
#    1217     )
#    1218 except ClientConnectorError as exc:
#    1219     last_exc = exc
#
# File /opt/conda/envs/custom/lib/python3.8/site-packages/aiohttp/connector.py:1000, in TCPConnector._wrap_create_connection(self, req, timeout, client_error, *args, **kwargs)
#     998 if exc.errno is None and isinstance(exc, asyncio.TimeoutError):
#     999     raise
# -> 1000 raise client_error(req.connection_key, exc) from exc
#
# ClientConnectorError: Cannot connect to host github.com:443 ssl:default [Connect call failed ('20.200.245.247', 443)]
